# %% [markdown]
# <a href="https://colab.research.google.com/github/9characters/Project/blob/master/DepthVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Cloning the repository to own notebook
# !git clone https://github.com/ialhashim/DenseDepth.git
# Out:
# Cloning into 'DenseDepth'...
# remote: Enumerating objects: 231, done.
# remote: Total 231 (delta 0), reused 0 (delta 0), pack-reused 231
# Receiving objects: 100% (231/231), 11.79 MiB | 17.79 MiB/s, done.
# Resolving deltas: 100% (113/113), done.

# %%
#Downloading the .h5 model to reconstruct the depth of an image
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./DenseDepth/nyu.h5
# Out:
# --2020-04-29 10:03:23--  https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.20.60
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.20.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172897376 (165M) [application/h5]
# Saving to: ‘./DenseDepth/nyu.h5’
#
# ./DenseDepth/nyu.h5 100%[===================>] 164.89M  21.2MB/s    in 8.6s
#
# 2020-04-29 10:03:33 (19.2 MB/s) - ‘./DenseDepth/nyu.h5’ saved [172897376/172897376]

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
cd DenseDepth
# Out:
# /content/DenseDepth

# %%
cd examples
# Out:
# /content/DenseDepth/examples

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b3823b66-0319-4810-bb7c-fc303dee83c0" name="files[]" multiple disabled />
#      <output id="result-b3823b66-0319-4810-bb7c-fc303dee83c0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test1.png to test1.png
# ...

# %%
#Converting the bit-depth of 32(RGBA) test1.png to 24(RGB)

from PIL import Image
im = Image.open("test1.png").convert('RGB')
im.save("test1.png")

# %%
#To visualize the single data, change the default argument parser to 'examples/test1.png'

# %%
cd ..
# Out:
# /content/DenseDepth

# %%
cd ..
# Out:
# /content

# %%
# !cd DenseDepth; python test.py
# Out:
# Using TensorFlow backend.
# Loading model...
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /content/DenseDepth/layers.py:38: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
#
# Model loaded (nyu.h5).
#
# Loaded (1) images of size (480, 640, 3).
# ...

# %%
#Test.png is created and now we visualize it

from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow(io.imread('./DenseDepth/test.png'))
